# %%
import random
print("Bem vindo ao jogo dos 21 fósforos")
print("Existem 21 fósforos você pode tirar 1-4 fósforos em cada jogador")
print("Quem ficar com o último fósforo perde")

def jogo():
    p= int(input("Se pretender jogar primeiro prima 1 , se pretender jogar em segundo prima 2:"))
    f=21
    if p==1:
        while f>0:
            jogada=int(input("Retire 1-4 fósforos:"))
            if jogada >4 or jogada <1:
                print("Jogada inválido. Tente novamente")
                jogada= int(input(("Retire 1-4 fósforos:")))
            else:
                pc=5-jogada
                print("O pc retirou", pc)
                f=f-jogada-pc
                print("Existem ",f, "atualmente")
                if f==1:
                    print("Game over")
                    op=input("Pretende jogar novamente? sim ou nao?:")
                    if op=="sim":
                        jogo()
                    else:
                        print("Bye")
                        break 
                   

    elif p==2:
            pc=random.randint(1,4)
            print("o pc retirou",pc,"fósforos")
            print("Existem atualmente", f-pc,"fósforos")
            jogada=int(input("Retire 1-4 fósforos"))
            f=f-pc-jogada
            print("Existem atualmente", f,"fósforos")
            
            if jogada> 4 or jogada <1:
                print("Erro. Tente novamente")
                jogada=int(input("Retire 1-4 fósforos"))
                f=f-pc-jogada
                print("Existem",f,"fósforos")
   
            while f>0:
                if pc+jogada<5:
                    pc=5-jogada-pc
                    print("o pc retirou",pc,"fósforos")
                    f=f-pc
                    print("Existem",f,"fósforos")
                    break

                
                elif pc+jogada>5:
                    pc=10-jogada-pc
                    print("o pc retirou",pc,"fósforos")
                    f=f-pc
                    print("Existem",f,"fósforos")
                    break
                
                else:
                    pc= random.randint(1,4)
                    print("O pc retirou",pc,"fósforos")
                    f=f-pc
                    print(f,"fósforos atuais")
                    jogada=int(input("Retire 1-4 fósforos"))
                    f=f-jogada
                    print(f,"fósforos atuais")
                                        
                    if f==1:
                            print("O jogador ganhou")
                            op=input("Pretende jogar novamente? sim ou nao?:")
                            if op=="sim":
                                        jogo()
                            else:
                                print("Bye")
                                break
                                
            jogada=int(input("Retire 1-4 fósforos"))
            
            while f>0:
                pc=5-jogada
                print("O pc retirou",pc, "fósforos")
                f=f-jogada-pc
                print("Existem atualmente",f, "fósforos")
                if f==1:
                    print("Game over")
                    op=input("Pretende jogar novamente? sim ou nao?")
                    if op=="sim":
                        jogo()
                    else:
                        print("Bye")
                        break
                else:
                    jogada=int(input("Retire 1-4 fósforos"))
        
    else:   
        print("O número que inseriu é inválido")
        jogo()
        
jogo()
